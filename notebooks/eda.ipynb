# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set Seaborn style for better visuals
sns.set(style="whitegrid")

# %%
# Load the dataset
df = pd.read_csv('../data/International_tourism.csv')

# Show the first 5 rows
df.head()
# Out:
#        Country                     Report Type       Category  \
# 0  AFGHANISTAN  Domestic Tourism-Accommodation  Accommodation
# 1  AFGHANISTAN  Domestic Tourism-Accommodation  Accommodation
# 2  AFGHANISTAN  Domestic Tourism-Accommodation  Accommodation
# 3  AFGHANISTAN  Domestic Tourism-Accommodation  Accommodation
# 4  AFGHANISTAN          Domestic Tourism-Trips          Trips
#
#                          Subcategory                          Metric  1995  \
# 0  Hotels and similar establishments                          Guests   NaN
# 1  Hotels and similar establishments                      Overnights   NaN
# 2                              Total                          Guests   NaN
# 3                              Total                      Overnights   NaN
# 4                        Total trips  Overnights visitors (tourists)   NaN
#
#    1996  1997  1998  1999  ...  2013  2014  2015  2016  2017  2018  2019  \
# ...

# %%
# Shape of the dataset (rows, columns)
print("Shape of the dataset:", df.shape)

# Info about columns and datatypes
df.info()
# Out:
# Shape of the dataset: (8253, 33)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8253 entries, 0 to 8252
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      8253 non-null   object
#  1   Report Type  8253 non-null   object
#  2   Category     8253 non-null   object
#  3   Subcategory  8253 non-null   object
#  4   Metric       8253 non-null   object
#  5   1995         2480 non-null   float64
#  6   1996         2523 non-null   float64
#  7   1997         2610 non-null   float64
#  8   1998         2680 non-null   float64
#  9   1999         2740 non-null   float64
#  10  2000         2841 non-null   float64
#  11  2001         2939 non-null   float64
#  12  2002         2967 non-null   float64
#  13  2003         3001 non-null   float64
#  14  2004         3042 non-null   float64
#  15  2005         3207 non-null   float64
#  16  2006         3341 non-null   float64
# ...

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# Country           0
# Report Type       0
# Category          0
# Subcategory       0
# Metric            0
# 1995           5773
# 1996           5730
# 1997           5643
# 1998           5573
# 1999           5513
# 2000           5412
# 2001           5314
# 2002           5286
# 2003           5252
# 2004           5211
# 2005           5046
# 2006           4912
# 2007           4779
# 2008           4733
# 2009           4694
# 2010           4630
# 2011           4629
# 2012           4608
# 2013           4573
# 2014           4528
# 2015           4461
# 2016           4444
# 2017           4480
# 2018           4509
# 2019           4564
# 2020           4773
# 2021           4958
# 2022           5542
# dtype: int64

# %%
# Summary stats for numeric columns
df.describe()
# Out:
#                1995          1996          1997          1998          1999  \
# count  2.480000e+03  2.523000e+03  2.610000e+03  2.680000e+03  2.740000e+03
# mean   1.588196e+04  1.633105e+04  1.645230e+04  1.702519e+04  1.734465e+04
# std    1.107553e+05  1.136524e+05  1.160610e+05  1.178732e+05  1.198386e+05
# min    1.100000e-02  1.759350e-02  1.000000e-01  2.000000e-01  1.000000e-01
# 25%    5.135250e+01  5.500000e+01  5.600000e+01  5.600000e+01  5.574200e+01
# 50%    3.720000e+02  3.930000e+02  4.035000e+02  4.325000e+02  4.360000e+02
# 75%    3.587750e+03  3.690500e+03  3.670000e+03  3.471000e+03  3.704500e+03
# max    3.500000e+06  3.600000e+06  3.800000e+06  3.900000e+06  3.900000e+06
#
#                2000          2001          2002          2003          2004  \
# count  2.841000e+03  2.939000e+03  2.967000e+03  3.001000e+03  3.042000e+03
# mean   1.795175e+04  1.745946e+04  1.776338e+04  1.812556e+04  1.898898e+04
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Report Type', 'Category', 'Subcategory', 'Metric', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
# Reshape from wide to long format
df_long = df.melt(
    id_vars=['Country', 'Report Type', 'Category', 'Subcategory', 'Metric'],
    var_name='Year',
    value_name='Value'
)

# Convert Year to numeric
df_long['Year'] = pd.to_numeric(df_long['Year'])

# Drop missing values if any
df_long = df_long.dropna()

# Show the reshaped data
df_long.head()
# Out:
#     Country                     Report Type  \
# 37  ALBANIA  Domestic Tourism-Accommodation
# 38  ALBANIA  Domestic Tourism-Accommodation
# 51  ALBANIA   Inbound Tourism-Accommodation
# 52  ALBANIA   Inbound Tourism-Accommodation
# 55  ALBANIA     Inbound Tourism-Expenditure
#
#                               Category                        Subcategory  \
# 37                       Accommodation  Hotels and similar establishments
# 38                       Accommodation  Hotels and similar establishments
# 51                       Accommodation  Hotels and similar establishments
# 52                       Accommodation  Hotels and similar establishments
# 55  Tourism expenditure in the country                Passenger transport
#
#                  Metric  Year  Value
# 37               Guests  1995  101.0
# 38           Overnights  1995  123.0
# 51               Guests  1995   41.0
# 52           Overnights  1995   89.0
# 55  Passenger transport  1995    5.0

# %%
# Filter for United Arab Emirates
uae_data = df_long[df_long['Country'] == 'United Arab Emirates']

# Plot the trend
plt.figure(figsize=(10, 5))
sns.lineplot(x='Year', y='Value', data=uae_data, marker='o')
plt.title('International Tourism in United Arab Emirates (1995–2022)')
plt.xlabel('Year')
plt.ylabel('Tourism Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# See all unique country names in the dataset
df_long['Country'].unique()
# Out:
# array(['ALBANIA', 'ALGERIA', 'ANGOLA', 'ANGUILLA', 'ANTIGUA AND BARBUDA',
#        'ARGENTINA', 'ARMENIA', 'ARUBA', 'AUSTRALIA', 'AUSTRIA',
#        'AZERBAIJAN', 'BAHAMAS', 'BAHRAIN', 'BANGLADESH', 'BARBADOS',
#        'BELARUS', 'BELGIUM', 'BELIZE', 'BENIN', 'BERMUDA', 'BHUTAN',
#        'BOLIVIA, PLURINATIONAL STATE OF', 'BONAIRE',
#        'BOSNIA AND HERZEGOVINA', 'BOTSWANA', 'BRAZIL',
#        'BRITISH VIRGIN ISLANDS', 'BRUNEI DARUSSALAM', 'BULGARIA',
#        'BURKINA FASO', 'BURUNDI', 'CABO VERDE', 'CAMBODIA', 'CAMEROON',
#        'CANADA', 'CAYMAN ISLANDS', 'CENTRAL AFRICAN REPUBLIC', 'CHAD',
#        'CHILE', 'CHINA', 'COLOMBIA', 'COMOROS', 'CONGO',
#        'CONGO, DEMOCRATIC REPUBLIC OF THE', 'COOK ISLANDS', 'COSTA RICA',
#        'COTE D´IVOIRE', 'CROATIA', 'CUBA', 'CURAÇAO', 'CYPRUS',
#        'CZECH REPUBLIC (CZECHIA)', 'DENMARK', 'DJIBOUTI', 'DOMINICA',
#        'DOMINICAN REPUBLIC', 'ECUADOR', 'EGYPT', 'EL SALVADOR',
# ...

# %%
# Filter for Egypt
egypt_data = df_long[df_long['Country'] == 'EGYPT']

# Plot the trend
plt.figure(figsize=(10, 5))
sns.lineplot(x='Year', y='Value', data=egypt_data, marker='o')
plt.title('International Tourism in Egypt (1995–2022)')
plt.xlabel('Year')
plt.ylabel('Tourism Value')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\hpdem\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\hpdem\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
